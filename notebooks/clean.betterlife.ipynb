# %% [markdown]
# # Better Life Index Cleaning Notebook
#
# Author: Dóra Kőhalmi
#
# This Jupyter Notebook cleans the data that was scraped from the "Country" section of the [Better Life Index]("https://www.oecdbetterlifeindex.org/#/11111111111") webpage by the scrape.betterlife.ipynb Jupyter Notebook.
#
# ----
# __Input:__
#     raw data: "/data/raw/betterlife_index.raw.csv"
#
# __Output:__
#     clean data: "/data/clean/betterlife.clean.csv"
#
# ## Steps
#
# 1. Load the scraped data (raw data) from "/data/raw/betterlife_index.raw.csv".
# 2. Inspect and clean all the columns
# 3. Write the cleaned dataframe into the "/data/clean/betterlife.clean.csv" file.
#
# The script version of this Notebook: /src/clean.betterlife.py.

# %%
import pandas as pd
import numpy as np
import re

# %%
# Set path to raw data:
path_to_betterlife_raw="../data/raw/betterlife.raw.csv"

# %%
pwd
# Out:
# 'C:\\Users\\kohal\\OneDrive\\Desktop\\Study\\HSLU_2_Semester\\CIP\\Project_Happiness\\CIP_FS25_202\\notebooks'

# %% [markdown]
# ## 1. Load Raw Data
#
# Load DataFrame with the scraped Better Life Index data

# %%
# inspect raw data:
df_raw = pd.read_csv(path_to_betterlife_raw)
df_raw
# Out:
#                Country  Population  Visitors  Renewable_Energy  Housing  \
# 0            Australia        24.9       6.1              4.60      8.2
# 1              Austria         8.9      18.9             29.50      6.3
# 2              Belgium        11.5       6.2              5.10      7.6
# 3               Brazil       209.5       5.2             45.80      4.7
# 4               Canada        37.1      25.3             17.90      7.8
# 5                Chile        18.7       3.6             24.10      6.7
# 6             Colombia        49.7       NaN               NaN      4.1
# 7           Costa Rica         NaN       NaN               NaN      6.3
# 8              Czechia        10.7      24.0              7.50      5.4
# 9              Denmark         5.8      20.6             24.40      6.3
# 10             Estonia         1.3       1.6             11.97      7.0
# 11             Finland         5.5       6.2             24.48      6.4
# 12              France        65.0      77.1              8.07      6.8
# 13             Germany        83.1      30.4             10.70      7.0
# 14              Greece        10.5      15.0              6.03      5.3
# 15             Hungary         9.7      21.1              8.00      5.8
# 16             Iceland         0.3       0.7             84.70      6.5
# 17             Ireland         4.8       6.0              6.10      7.4
# 18              Israel         8.4       3.5              4.88      5.2
# 19               Italy        60.6      76.3             13.20      5.5
# 20               Japan       127.2       8.4              4.20      6.1
# 21               Korea        51.2      11.1              0.70      7.5
# 22              Latvia         1.9       6.2               NaN      4.5
# 23           Lithuania         NaN       NaN               NaN      5.8
# 24          Luxembourg         0.6       0.9              3.20      7.1
# 25              Mexico       126.2      76.7              8.70      3.7
# 26         Netherlands        17.1      11.2              4.30      7.5
# 27         New Zealand         4.7       2.6             38.30      6.8
# 28              Norway         5.3       2.5             46.90      8.1
# 29              Poland        37.9      67.4              8.80      5.1
# 30            Portugal        10.3       7.7             21.20      6.8
# 31  Russian Federation       145.7      23.7              2.80      4.7
# 32     Slovak Republic         5.5       8.8              7.60      3.6
# 33            Slovenia         2.1       2.2             13.90      6.9
# 34        South Africa        52.4      14.5             11.00      2.6
# 35               Spain        46.1      99.2             11.90      6.7
# 36              Sweden        10.0      16.0             35.60      6.9
# 37         Switzerland         8.5       8.6             20.50      6.9
# 38             Türkiye        82.3      37.7             10.20      5.2
# 39      United Kingdom        67.1      31.1              4.50      6.5
# 40       United States       311.6     171.6              6.30      8.6
#
#     Income  Jobs  Community  Education  Environment  ...  \
# 0      5.9   8.6        7.7        8.6          8.9  ...
# 1      4.7   8.5        7.2        6.8          7.6  ...
# 2      5.2   8.0        6.0        7.9          5.8  ...
# 3      0.5   4.3        2.7        2.3          4.8  ...
# 4      5.3   8.4        7.5        7.8          8.6  ...
# 5      1.4   5.5        5.3        4.5          1.1  ...
# 6      0.5   5.2        1.3        1.4          4.1  ...
# 7      1.1   5.2        2.6        2.0          5.9  ...
# 8      2.5   7.7        9.1        7.8          6.3  ...
# 9      3.3   8.7        8.3        8.0          8.3  ...
# 10     2.4   7.3        8.4        8.2          8.2  ...
# 11     3.8   8.2        8.9        9.2          9.8  ...
# 12     4.3   7.5        8.2        6.3          6.0  ...
# 13     4.8   8.9        6.2        7.6          7.7  ...
# 14     1.8   3.0        0.5        6.4          3.9  ...
# 15     1.8   7.0        7.9        6.2          5.2  ...
# 16     6.4   9.7       10.0        6.8          9.7  ...
# 17     4.1   8.1        8.9        7.6          7.1  ...
# 18     3.7   7.5        8.6        5.5          4.0  ...
# 19     3.6   5.8        5.6        4.9          5.0  ...
# 20     3.6   8.3        5.5        7.7          6.7  ...
# 21     3.4   7.8        1.5        7.8          3.1  ...
# 22     1.3   6.9        7.1        7.5          6.4  ...
# 23     2.7   7.0        5.5        7.7          6.9  ...
# 24     9.3   8.7        6.5        4.7          7.2  ...
# 25     1.1   6.2        0.0        1.3          3.6  ...
# 26     4.1   9.1        8.0        7.7          7.6  ...
# 27     6.0   8.3        8.5        7.0          8.1  ...
# 28     4.6   8.8        8.7        7.4          9.8  ...
# 29     2.6   7.2        8.0        8.1          4.1  ...
# 30     2.9   6.5        4.8        4.9          8.1  ...
# 31     1.3   7.0        5.5        6.8          3.6  ...
# 32     2.0   6.0        8.4        5.9          4.8  ...
# 33     2.8   7.5        8.5        8.1          6.8  ...
# 34     0.1   0.0        5.7        1.0          1.4  ...
# 35     3.8   5.3        7.8        5.6          5.9  ...
# 36     5.0   8.3        7.8        8.3          9.8  ...
# 37     8.2   9.4        8.2        7.4          8.7  ...
# 38     1.3   4.4        3.7        4.2          0.3  ...
# 39     5.4   8.4        7.3        6.7          6.8  ...
# 40     8.5   8.8        7.8        7.4          8.2  ...
#
#     Gender_Inequality_Satisfaction  Social_Inequality_Satisfaction  \
# 0                             1.02                            1.06
# 1                             1.03                            1.05
# 2                             1.01                            1.08
# 3                             1.03                            1.09
# 4                             1.00                            1.05
# 5                             1.02                            1.13
# 6                             1.01                            1.26
# 7                             1.04                            1.08
# 8                             1.00                            1.10
# 9                             1.03                            1.02
# 10                            1.03                            1.16
# 11                            1.04                            1.07
# 12                            1.01                            1.04
# 13                            1.01                            1.09
# 14                            1.09                            1.13
# 15                            1.08                            1.15
# 16                            1.05                             NaN
# 17                            1.04                            1.04
# 18                            1.01                            1.05
# 19                            1.02                            1.05
# 20                            1.06                            1.07
# 21                            1.13                            1.15
# 22                            1.03                            1.10
# 23                            1.08                            1.15
# 24                            1.01                            1.06
# 25                            1.12                            1.14
# 26                            1.02                            1.05
# 27                            1.03                            1.01
# 28                            1.01                            1.02
# 29                            1.04                            1.10
# 30                            1.07                            1.12
# 31                            1.06                            1.11
# 32                            1.02                            1.08
# 33                            1.01                             NaN
# 34                            1.01                            1.14
# 35                            1.02                            1.07
# 36                            1.00                            1.04
# 37                            1.00                            1.02
# 38                            1.26                            1.19
# 39                            1.02                            1.07
# 40                            1.01                            1.09
#
#     Safe_at_Night  Gender_Inequality_Safety   Homicide_Rate  \
# 0          66.95%                      1.50   0.9 homicides
# 1          85.68%                      1.09   0.5 homicides
# 2           56.5%                      1.42   1.1 homicides
# 3          44.78%                      1.61    19 homicides
# 4           77.5%                      1.31   1.2 homicides
# 5          40.69%                      1.77   2.4 homicides
# 6          49.52%                      1.19  23.1 homicides
# 7          47.12%                      1.62    10 homicides
# 8          77.43%                      1.31   0.7 homicides
# 9          85.26%                      1.23   0.5 homicides
# 10         79.49%                      1.27   1.9 homicides
# 11         87.55%                      1.20   1.2 homicides
# 12         73.97%                      1.11   0.4 homicides
# 13         76.15%                      1.20   0.4 homicides
# 14          68.8%                      1.33     1 homicides
# 15         73.71%                      1.28   0.9 homicides
# 16         85.38%                      1.20   0.3 homicides
# 17         76.32%                      1.27   0.5 homicides
# 18         79.77%                      1.09   1.5 homicides
# 19         72.82%                      1.18   0.5 homicides
# 20         76.75%                      1.23   0.2 homicides
# 21         82.02%                      1.14   0.8 homicides
# 22         72.32%                      1.42   3.7 homicides
# 23         62.22%                      1.24  2.47 homicides
# 24         86.55%                      1.07   0.2 homicides
# 25         42.28%                      1.69  26.8 homicides
# 26         83.16%                      1.31   0.6 homicides
# 27         66.15%                      1.50   1.3 homicides
# 28         93.16%                      1.10   0.6 homicides
# 29         71.14%                      1.26   0.5 homicides
# 30         82.88%                      1.22   0.7 homicides
# 31         63.59%                      1.34   4.8 homicides
# 32         75.87%                      1.27   0.8 homicides
# 33         90.56%                      1.12   0.4 homicides
# 34         39.98%                      1.31  13.7 homicides
# 35          80.4%                      1.15   0.7 homicides
# 36         79.25%                      1.32   1.1 homicides
# 37          85.9%                      1.13   0.3 homicides
# 38         58.66%                      1.60     1 homicides
# 39         78.36%                      1.04   0.2 homicides
# 40         78.07%                      1.27     6 homicides
#
#    Gender_Inequality_Homicide Long_Hours Gender_Inequality_Long_Hours  \
# 0                        2.17      12.5%                         3.06
# 1                        1.00       5.3%                         3.45
# 2                        1.75       4.3%                         2.21
# 3                       10.76       5.6%                         2.03
# 4                        2.57       3.3%                         4.50
# 5                        6.00       7.7%                         1.93
# 6                       10.49      23.7%                         1.65
# 7                       10.11        22%                         2.20
# 8                        1.33       4.5%                         3.40
# 9                        1.75       1.1%                        20.77
# 10                       5.17       2.2%                         2.25
# 11                       2.57       3.6%                         2.47
# 12                       2.00       7.7%                         1.96
# 13                       1.33       3.9%                         3.11
# 14                       4.00       4.5%                         2.43
# 15                       1.62       1.5%                         2.27
# 16                       2.40      11.7%                         3.56
# 17                       8.00       4.7%                         4.69
# 18                       3.43      14.1%                         3.17
# 19                       2.33       3.3%                         2.00
# 20                       1.00     ~15.7%                          NaN
# 21                       1.29     ~19.7%                          NaN
# 22                       3.05       1.6%                         2.51
# 23                       4.17         1%                         1.40
# 24                       1.50       2.8%                         1.66
# 25                       9.18        27%                         1.90
# 26                       2.00       0.3%                         5.97
# 27                       1.60        14%                         2.25
# 28                       1.40       1.4%                         3.72
# 29                       2.67       4.2%                         5.04
# 30                       2.50       5.6%                         2.46
# 31                       3.50       0.1%                         3.62
# 32                       1.67       4.2%                         3.02
# 33                       1.67       5.6%                         2.69
# 34                       6.86      15.4%                         1.89
# 35                       1.80       2.5%                         2.52
# 36                       3.00       0.9%                         2.64
# 37                       1.33       0.4%                         1.61
# 38                       3.00        25%                         1.35
# 39                       2.00      10.8%                         2.43
# 40                       3.80      10.4%                         2.09
#
#       Free_Time  Gender_Inequality_Free_Time
# 0    14.4 hours                         1.08
# 1    14.5 hours                         1.02
# 2    15.5 hours                         1.02
# 3   ~14.6 hours                          NaN
# 4    14.6 hours                         1.01
# 5   ~14.0 hours                          NaN
# 6   ~13.3 hours                          NaN
# 7   ~13.5 hours                          NaN
# 8   ~15.1 hours                          NaN
# 9   ~15.7 hours                          NaN
# 10     15 hours                         1.06
# 11   15.2 hours                         1.02
# 12   16.2 hours                         1.03
# 13   15.6 hours                         1.01
# 14     15 hours                         1.04
# 15   15.1 hours                         1.07
# 16  ~14.5 hours                          NaN
# 17   14.5 hours                         1.01
# 18  ~14.3 hours                          NaN
# 19   16.5 hours                         1.09
# 20   14.1 hours                         1.02
# 21   14.8 hours                         1.04
# 22  ~15.1 hours                          NaN
# 23  ~15.1 hours                          NaN
# 24  ~15.1 hours                          NaN
# 25  ~13.5 hours                          NaN
# 26   15.4 hours                         1.02
# 27   14.9 hours                         1.00
# 28   15.7 hours                         1.09
# 29   14.7 hours                         1.04
# 30  ~15.0 hours                          NaN
# 31  ~15.1 hours                          NaN
# 32  ~15.1 hours                          NaN
# 33  ~15.0 hours                          NaN
# 34  ~14.2 hours                          NaN
# 35   15.7 hours                         1.06
# 36  ~15.3 hours                          NaN
# 37  ~15.0 hours                          NaN
# 38   14.6 hours                         1.05
# 39   14.9 hours                         1.01
# 40   14.6 hours                         1.03
#
# [41 rows x 63 columns]

# %% [markdown]
# ## 2. Inspect Data

# %%
# Column names:
df_raw.columns
# Out:
# Index(['Country', 'Population', 'Visitors', 'Renewable_Energy', 'Housing',
#        'Income', 'Jobs', 'Community', 'Education', 'Environment',
#        'Civic_Engagement', 'Health', 'Life_Satisfaction', 'Safety',
#        'Work_Life_Balance', 'Rooms_per_person', 'Basic_Facilities',
#        'Housing_Expenditure', 'Net_Disposable_Income',
#        'Social_Inequality_Income', 'Net_wealth', 'Employment_Rate',
#        'Gender_Inequality_Employment', 'Social_Inequality_Employment',
#        'Long_Term_Unemployment', 'Gender_Inequality_Unemployment',
#        'Social_Inequality_Unemployment', 'Personal_Earnings',
#        'Gender_Inequality_Earnings', 'Social_Inequality_Earnings',
#        'Job_Security', 'Quality_of_Support_Network',
#        'Gender_Inequality_Community', 'Social_Inequality_Community',
#        'Educational_Attainment', 'Gender_Inequality_Education',
#        'Student_Skills', 'Gender_Inequality_Skills',
#        'Social_Inequality_Skills', 'Years_in_Education',
#        'Gender_Inequality_Years_Education', 'Air_Pollution', 'Water_Quality',
#        'Voter_Turnout', 'Gender_Inequality_Voter', 'Social_Inequality_Voter',
#        'Stakeholder_Engagement', 'Life_Expectancy',
#        'Gender_Inequality_Life_Expectancy', 'Self_Reported_Health',
#        'Gender_Inequality_Health', 'Social_Inequality_Health',
#        'Life_Satisfaction_2', 'Gender_Inequality_Satisfaction',
#        'Social_Inequality_Satisfaction', 'Safe_at_Night',
#        'Gender_Inequality_Safety', 'Homicide_Rate',
#        'Gender_Inequality_Homicide', 'Long_Hours',
#        'Gender_Inequality_Long_Hours', 'Free_Time',
#        'Gender_Inequality_Free_Time'],
#       dtype='object')

# %%
#  Information about missing values and data type of the columns:
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 63 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            41 non-null     object
#  1   Population                         39 non-null     float64
#  2   Visitors                           38 non-null     float64
#  3   Renewable_Energy                   37 non-null     float64
#  4   Housing                            41 non-null     float64
#  5   Income                             41 non-null     float64
#  6   Jobs                               41 non-null     float64
#  7   Community                          41 non-null     float64
#  8   Education                          41 non-null     float64
#  9   Environment                        41 non-null     float64
#  10  Civic_Engagement                   41 non-null     float64
#  11  Health                             41 non-null     float64
#  12  Life_Satisfaction                  41 non-null     float64
#  13  Safety                             41 non-null     float64
#  14  Work_Life_Balance                  41 non-null     float64
#  15  Rooms_per_person                   41 non-null     object
#  16  Basic_Facilities                   41 non-null     object
#  17  Housing_Expenditure                41 non-null     object
#  18  Net_Disposable_Income              41 non-null     object
#  19  Social_Inequality_Income           35 non-null     float64
#  20  Net_wealth                         41 non-null     object
#  21  Employment_Rate                    41 non-null     object
#  22  Gender_Inequality_Employment       41 non-null     float64
#  23  Social_Inequality_Employment       38 non-null     float64
#  24  Long_Term_Unemployment             41 non-null     object
#  25  Gender_Inequality_Unemployment     39 non-null     float64
#  26  Social_Inequality_Unemployment     33 non-null     float64
#  27  Personal_Earnings                  41 non-null     object
#  28  Gender_Inequality_Earnings         33 non-null     float64
#  29  Social_Inequality_Earnings         32 non-null     float64
#  30  Job_Security                       41 non-null     object
#  31  Quality_of_Support_Network         41 non-null     object
#  32  Gender_Inequality_Community        41 non-null     float64
#  33  Social_Inequality_Community        39 non-null     float64
#  34  Educational_Attainment             41 non-null     object
#  35  Gender_Inequality_Education        40 non-null     float64
#  36  Student_Skills                     41 non-null     object
#  37  Gender_Inequality_Skills           39 non-null     float64
#  38  Social_Inequality_Skills           39 non-null     float64
#  39  Years_in_Education                 41 non-null     object
#  40  Gender_Inequality_Years_Education  39 non-null     float64
#  41  Air_Pollution                      41 non-null     object
#  42  Water_Quality                      41 non-null     object
#  43  Voter_Turnout                      41 non-null     object
#  44  Gender_Inequality_Voter            39 non-null     float64
#  45  Social_Inequality_Voter            35 non-null     float64
#  46  Stakeholder_Engagement             41 non-null     object
#  47  Life_Expectancy                    41 non-null     object
#  48  Gender_Inequality_Life_Expectancy  41 non-null     float64
#  49  Self_Reported_Health               41 non-null     object
#  50  Gender_Inequality_Health           39 non-null     float64
#  51  Social_Inequality_Health           35 non-null     float64
#  52  Life_Satisfaction_2                41 non-null     object
#  53  Gender_Inequality_Satisfaction     41 non-null     float64
#  54  Social_Inequality_Satisfaction     39 non-null     float64
#  55  Safe_at_Night                      41 non-null     object
#  56  Gender_Inequality_Safety           41 non-null     float64
#  57  Homicide_Rate                      41 non-null     object
#  58  Gender_Inequality_Homicide         41 non-null     float64
#  59  Long_Hours                         41 non-null     object
#  60  Gender_Inequality_Long_Hours       39 non-null     float64
#  61  Free_Time                          41 non-null     object
#  62  Gender_Inequality_Free_Time        22 non-null     float64
# dtypes: float64(38), object(25)
# memory usage: 20.3+ KB

# %% [markdown]
# ### 2.1 Missing data in the data frame:

# %%
df_raw.isnull().sum()
# Out:
# Country                          0
# Population                       2
# Visitors                         3
# Renewable_Energy                 4
# Housing                          0
#                                 ..
# Gender_Inequality_Homicide       0
# Long_Hours                       0
# Gender_Inequality_Long_Hours     2
# Free_Time                        0
# Gender_Inequality_Free_Time     19
# Length: 63, dtype: int64

# %%
print("Total number of missing values in the data frame: ", df_raw.isnull().sum().sum())
# Out:
# Total number of missing values in the data frame:  93

# %%
df_raw[df_raw.isnull().any(axis=1)]
# Out:
#                Country  Population  Visitors  Renewable_Energy  Housing  \
# 2              Belgium        11.5       6.2              5.10      7.6
# 3               Brazil       209.5       5.2             45.80      4.7
# 5                Chile        18.7       3.6             24.10      6.7
# 6             Colombia        49.7       NaN               NaN      4.1
# 7           Costa Rica         NaN       NaN               NaN      6.3
# 8              Czechia        10.7      24.0              7.50      5.4
# 9              Denmark         5.8      20.6             24.40      6.3
# 16             Iceland         0.3       0.7             84.70      6.5
# 17             Ireland         4.8       6.0              6.10      7.4
# 18              Israel         8.4       3.5              4.88      5.2
# 20               Japan       127.2       8.4              4.20      6.1
# 21               Korea        51.2      11.1              0.70      7.5
# 22              Latvia         1.9       6.2               NaN      4.5
# 23           Lithuania         NaN       NaN               NaN      5.8
# 24          Luxembourg         0.6       0.9              3.20      7.1
# 25              Mexico       126.2      76.7              8.70      3.7
# 27         New Zealand         4.7       2.6             38.30      6.8
# 28              Norway         5.3       2.5             46.90      8.1
# 30            Portugal        10.3       7.7             21.20      6.8
# 31  Russian Federation       145.7      23.7              2.80      4.7
# 32     Slovak Republic         5.5       8.8              7.60      3.6
# 33            Slovenia         2.1       2.2             13.90      6.9
# 34        South Africa        52.4      14.5             11.00      2.6
# 35               Spain        46.1      99.2             11.90      6.7
# 36              Sweden        10.0      16.0             35.60      6.9
# 37         Switzerland         8.5       8.6             20.50      6.9
# 38             Türkiye        82.3      37.7             10.20      5.2
#
#     Income  Jobs  Community  Education  Environment  ...  \
# 2      5.2   8.0        6.0        7.9          5.8  ...
# 3      0.5   4.3        2.7        2.3          4.8  ...
# 5      1.4   5.5        5.3        4.5          1.1  ...
# 6      0.5   5.2        1.3        1.4          4.1  ...
# 7      1.1   5.2        2.6        2.0          5.9  ...
# 8      2.5   7.7        9.1        7.8          6.3  ...
# 9      3.3   8.7        8.3        8.0          8.3  ...
# 16     6.4   9.7       10.0        6.8          9.7  ...
# 17     4.1   8.1        8.9        7.6          7.1  ...
# 18     3.7   7.5        8.6        5.5          4.0  ...
# 20     3.6   8.3        5.5        7.7          6.7  ...
# 21     3.4   7.8        1.5        7.8          3.1  ...
# 22     1.3   6.9        7.1        7.5          6.4  ...
# 23     2.7   7.0        5.5        7.7          6.9  ...
# 24     9.3   8.7        6.5        4.7          7.2  ...
# 25     1.1   6.2        0.0        1.3          3.6  ...
# 27     6.0   8.3        8.5        7.0          8.1  ...
# 28     4.6   8.8        8.7        7.4          9.8  ...
# 30     2.9   6.5        4.8        4.9          8.1  ...
# 31     1.3   7.0        5.5        6.8          3.6  ...
# 32     2.0   6.0        8.4        5.9          4.8  ...
# 33     2.8   7.5        8.5        8.1          6.8  ...
# 34     0.1   0.0        5.7        1.0          1.4  ...
# 35     3.8   5.3        7.8        5.6          5.9  ...
# 36     5.0   8.3        7.8        8.3          9.8  ...
# 37     8.2   9.4        8.2        7.4          8.7  ...
# 38     1.3   4.4        3.7        4.2          0.3  ...
#
#     Gender_Inequality_Satisfaction  Social_Inequality_Satisfaction  \
# 2                             1.01                            1.08
# 3                             1.03                            1.09
# 5                             1.02                            1.13
# 6                             1.01                            1.26
# 7                             1.04                            1.08
# 8                             1.00                            1.10
# 9                             1.03                            1.02
# 16                            1.05                             NaN
# 17                            1.04                            1.04
# 18                            1.01                            1.05
# 20                            1.06                            1.07
# 21                            1.13                            1.15
# 22                            1.03                            1.10
# 23                            1.08                            1.15
# 24                            1.01                            1.06
# 25                            1.12                            1.14
# 27                            1.03                            1.01
# 28                            1.01                            1.02
# 30                            1.07                            1.12
# 31                            1.06                            1.11
# 32                            1.02                            1.08
# 33                            1.01                             NaN
# 34                            1.01                            1.14
# 35                            1.02                            1.07
# 36                            1.00                            1.04
# 37                            1.00                            1.02
# 38                            1.26                            1.19
#
#     Safe_at_Night  Gender_Inequality_Safety   Homicide_Rate  \
# 2           56.5%                      1.42   1.1 homicides
# 3          44.78%                      1.61    19 homicides
# 5          40.69%                      1.77   2.4 homicides
# 6          49.52%                      1.19  23.1 homicides
# 7          47.12%                      1.62    10 homicides
# 8          77.43%                      1.31   0.7 homicides
# 9          85.26%                      1.23   0.5 homicides
# 16         85.38%                      1.20   0.3 homicides
# 17         76.32%                      1.27   0.5 homicides
# 18         79.77%                      1.09   1.5 homicides
# 20         76.75%                      1.23   0.2 homicides
# 21         82.02%                      1.14   0.8 homicides
# 22         72.32%                      1.42   3.7 homicides
# 23         62.22%                      1.24  2.47 homicides
# 24         86.55%                      1.07   0.2 homicides
# 25         42.28%                      1.69  26.8 homicides
# 27         66.15%                      1.50   1.3 homicides
# 28         93.16%                      1.10   0.6 homicides
# 30         82.88%                      1.22   0.7 homicides
# 31         63.59%                      1.34   4.8 homicides
# 32         75.87%                      1.27   0.8 homicides
# 33         90.56%                      1.12   0.4 homicides
# 34         39.98%                      1.31  13.7 homicides
# 35          80.4%                      1.15   0.7 homicides
# 36         79.25%                      1.32   1.1 homicides
# 37          85.9%                      1.13   0.3 homicides
# 38         58.66%                      1.60     1 homicides
#
#    Gender_Inequality_Homicide Long_Hours Gender_Inequality_Long_Hours  \
# 2                        1.75       4.3%                         2.21
# 3                       10.76       5.6%                         2.03
# 5                        6.00       7.7%                         1.93
# 6                       10.49      23.7%                         1.65
# 7                       10.11        22%                         2.20
# 8                        1.33       4.5%                         3.40
# 9                        1.75       1.1%                        20.77
# 16                       2.40      11.7%                         3.56
# 17                       8.00       4.7%                         4.69
# 18                       3.43      14.1%                         3.17
# 20                       1.00     ~15.7%                          NaN
# 21                       1.29     ~19.7%                          NaN
# 22                       3.05       1.6%                         2.51
# 23                       4.17         1%                         1.40
# 24                       1.50       2.8%                         1.66
# 25                       9.18        27%                         1.90
# 27                       1.60        14%                         2.25
# 28                       1.40       1.4%                         3.72
# 30                       2.50       5.6%                         2.46
# 31                       3.50       0.1%                         3.62
# 32                       1.67       4.2%                         3.02
# 33                       1.67       5.6%                         2.69
# 34                       6.86      15.4%                         1.89
# 35                       1.80       2.5%                         2.52
# 36                       3.00       0.9%                         2.64
# 37                       1.33       0.4%                         1.61
# 38                       3.00        25%                         1.35
#
#       Free_Time  Gender_Inequality_Free_Time
# 2    15.5 hours                         1.02
# 3   ~14.6 hours                          NaN
# 5   ~14.0 hours                          NaN
# 6   ~13.3 hours                          NaN
# 7   ~13.5 hours                          NaN
# 8   ~15.1 hours                          NaN
# 9   ~15.7 hours                          NaN
# 16  ~14.5 hours                          NaN
# 17   14.5 hours                         1.01
# 18  ~14.3 hours                          NaN
# 20   14.1 hours                         1.02
# 21   14.8 hours                         1.04
# 22  ~15.1 hours                          NaN
# 23  ~15.1 hours                          NaN
# 24  ~15.1 hours                          NaN
# 25  ~13.5 hours                          NaN
# 27   14.9 hours                         1.00
# 28   15.7 hours                         1.09
# 30  ~15.0 hours                          NaN
# 31  ~15.1 hours                          NaN
# 32  ~15.1 hours                          NaN
# 33  ~15.0 hours                          NaN
# 34  ~14.2 hours                          NaN
# 35   15.7 hours                         1.06
# 36  ~15.3 hours                          NaN
# 37  ~15.0 hours                          NaN
# 38   14.6 hours                         1.05
#
# [27 rows x 63 columns]

# %%
# Check column "Country":
print(df_raw["Country"].unique())
print("Number of unique values in this column: ", df_raw["Country"].nunique())
print("Length of data frame: ", len(df_raw))

#Conclusion: All value different, no missing values, clean column.
# Out:
# ['Australia' 'Austria' 'Belgium' 'Brazil' 'Canada' 'Chile' 'Colombia'
#  'Costa Rica' 'Czechia' 'Denmark' 'Estonia' 'Finland' 'France' 'Germany'
#  'Greece' 'Hungary' 'Iceland' 'Ireland' 'Israel' 'Italy' 'Japan' 'Korea'
#  'Latvia' 'Lithuania' 'Luxembourg' 'Mexico' 'Netherlands' 'New Zealand'
#  'Norway' 'Poland' 'Portugal' 'Russian Federation' 'Slovak Republic'
#  'Slovenia' 'South Africa' 'Spain' 'Sweden' 'Switzerland' 'Türkiye'
#  'United Kingdom' 'United States']
# Number of unique values in this column:  41
# Length of data frame:  41

# %% [markdown]
# ### 2.2 Unique values in each column:
#
# Let's take a look at the unique values in each column. We can observe that
#
# - there are columns with missing values (nan), we knew it already from .info()
# - there are columns with "object" data type because there is some text before or/and after the numeric value (~65.2%), these extra strings need to be removed

# %%
for col in df_raw.columns:
    print(f"Column {col}:")
    print("----------------------")
    print(f"Data type of column {col}: ", df_raw[col].dtype)
    print(f"Unique values in column {col}:")
    print(df_raw[col].unique())
    print()
# Out:
# Column Country:
# ----------------------
# Data type of column Country:  object
# Unique values in column Country:
# ['Australia' 'Austria' 'Belgium' 'Brazil' 'Canada' 'Chile' 'Colombia'
#  'Costa Rica' 'Czechia' 'Denmark' 'Estonia' 'Finland' 'France' 'Germany'
#  'Greece' 'Hungary' 'Iceland' 'Ireland' 'Israel' 'Italy' 'Japan' 'Korea'
#  'Latvia' 'Lithuania' 'Luxembourg' 'Mexico' 'Netherlands' 'New Zealand'
#  'Norway' 'Poland' 'Portugal' 'Russian Federation' 'Slovak Republic'
#  'Slovenia' 'South Africa' 'Spain' 'Sweden' 'Switzerland' 'Türkiye'
#  'United Kingdom' 'United States']
#
# Column Population:
# ----------------------
# Data type of column Population:  float64
# Unique values in column Population:
# [2.490e+01 8.900e+00 1.150e+01 2.095e+02 3.710e+01 1.870e+01 4.970e+01
#        nan 1.070e+01 5.800e+00 1.300e+00 5.500e+00 6.500e+01 8.310e+01
#  1.050e+01 9.700e+00 3.000e-01 4.800e+00 8.400e+00 6.060e+01 1.272e+02
#  5.120e+01 1.900e+00 6.000e-01 1.262e+02 1.710e+01 4.700e+00 5.300e+00
#  3.790e+01 1.030e+01 1.457e+02 2.100e+00 5.240e+01 4.610e+01 1.000e+01
#  8.500e+00 8.230e+01 6.710e+01 3.116e+02]
#
# Column Visitors:
# ----------------------
# Data type of column Visitors:  float64
# Unique values in column Visitors:
# [  6.1  18.9   6.2   5.2  25.3   3.6   nan  24.   20.6   1.6  77.1  30.4
#   15.   21.1   0.7   6.    3.5  76.3   8.4  11.1   0.9  76.7  11.2   2.6
#    2.5  67.4   7.7  23.7   8.8   2.2  14.5  99.2  16.    8.6  37.7  31.1
#  171.6]
#
# Column Renewable_Energy:
# ----------------------
# Data type of column Renewable_Energy:  float64
# Unique values in column Renewable_Energy:
# [ 4.6  29.5   5.1  45.8  17.9  24.1    nan  7.5  24.4  11.97 24.48  8.07
#  10.7   6.03  8.   84.7   6.1   4.88 13.2   4.2   0.7   3.2   8.7   4.3
#  38.3  46.9   8.8  21.2   2.8   7.6  13.9  11.   11.9  35.6  20.5  10.2
#   4.5   6.3 ]
#
# Column Housing:
# ----------------------
# Data type of column Housing:  float64
# Unique values in column Housing:
# [8.2 6.3 7.6 4.7 7.8 6.7 4.1 5.4 7.  6.4 6.8 5.3 5.8 6.5 7.4 5.2 5.5 6.1
#  7.5 4.5 7.1 3.7 8.1 5.1 3.6 6.9 2.6 8.6]
#
# Column Income:
# ----------------------
# Data type of column Income:  float64
# Unique values in column Income:
# [5.9 4.7 5.2 0.5 5.3 1.4 1.1 2.5 3.3 2.4 3.8 4.3 4.8 1.8 6.4 4.1 3.7 3.6
#  3.4 1.3 2.7 9.3 6.  4.6 2.6 2.9 2.  2.8 0.1 5.  8.2 5.4 8.5]
#
# Column Jobs:
# ----------------------
# Data type of column Jobs:  float64
# Unique values in column Jobs:
# [8.6 8.5 8.  4.3 8.4 5.5 5.2 7.7 8.7 7.3 8.2 7.5 8.9 3.  7.  9.7 8.1 5.8
#  8.3 7.8 6.9 6.2 9.1 8.8 7.2 6.5 6.  0.  5.3 9.4 4.4]
#
# Column Community:
# ----------------------
# Data type of column Community:  float64
# Unique values in column Community:
# [ 7.7  7.2  6.   2.7  7.5  5.3  1.3  2.6  9.1  8.3  8.4  8.9  8.2  6.2
#   0.5  7.9 10.   8.6  5.6  5.5  1.5  7.1  6.5  0.   8.   8.5  8.7  4.8
#   5.7  7.8  3.7  7.3]
#
# Column Education:
# ----------------------
# Data type of column Education:  float64
# Unique values in column Education:
# [8.6 6.8 7.9 2.3 7.8 4.5 1.4 2.  8.  8.2 9.2 6.3 7.6 6.4 6.2 5.5 4.9 7.7
#  7.5 4.7 1.3 7.  7.4 8.1 5.9 1.  5.6 8.3 4.2 6.7]
#
# Column Environment:
# ----------------------
# Data type of column Environment:  float64
# Unique values in column Environment:
# [8.9 7.6 5.8 4.8 8.6 1.1 4.1 5.9 6.3 8.3 8.2 9.8 6.  7.7 3.9 5.2 9.7 7.1
#  4.  5.  6.7 3.1 6.4 6.9 7.2 3.6 8.1 6.8 1.4 8.7 0.3]
#
# Column Civic_Engagement:
# ----------------------
# Data type of column Civic_Engagement:  float64
# Unique values in column Civic_Engagement:
# [8.9 4.3 7.2 6.7 6.8 1.2 2.1 3.5 6.  5.4 5.8 5.3 3.4 6.6 2.9 2.  7.8 4.
#  4.7 7.  7.4 7.5 6.5 6.3 1.8 2.4 3.9 5.  6.9 3.2 5.9 7.1]
#
# Column Health:
# ----------------------
# Data type of column Health:  float64
# Unique values in column Health:
# [9.3 7.8 8.1 6.2 9.5 6.4 7.3 7.7 6.3 7.5 5.6 7.6 7.1 8.4 5.2 8.6 9.2 8.3
#  5.3 4.8 4.  4.1 8.  8.2 5.8 3.1 8.7 6.6]
#
# Column Life_Satisfaction:
# ----------------------
# Data type of column Life_Satisfaction:  float64
# Unique values in column Life_Satisfaction:
# [ 7.5  7.8  6.5  4.1  7.1  4.3  2.8  4.9  6.7  8.8  5.3 10.   6.1  8.1
#   3.1  3.9  9.   7.2  7.7  5.4  4.5  5.1  8.4  3.6  8.7  7.9  8.   4.2
#   3.   2.1  5.5  0.3  0.   6.4]
#
# Column Safety:
# ----------------------
# Data type of column Safety:  float64
# Unique values in column Safety:
# [7.4 9.3 6.4 1.9 8.3 4.7 1.6 3.8 8.4 9.2 8.1 7.5 8.  8.5 8.8 6.7 9.4 0.2
#  8.9 7.3 9.9 7.9 6.3 9.7 2.5 8.7 8.6 6.6]
#
# Column Work_Life_Balance:
# ----------------------
# Data type of column Work_Life_Balance:  float64
# Unique values in column Work_Life_Balance:
# [4.4 6.  7.7 6.2 6.5 4.8 0.6 1.3 7.  8.6 7.3 8.1 8.  7.6 4.  9.4 3.4 3.8
#  7.5 7.4 0.4 8.3 4.9 8.5 6.7 7.8 7.1 3.6 8.4 2.5 5.6 5.2]
#
# Column Rooms_per_person:
# ----------------------
# Data type of column Rooms_per_person:  object
# Unique values in column Rooms_per_person:
# ['~2.3 rooms' '1.6 rooms' '2.1 rooms' '~1.1 rooms' '2.6 rooms' '1.9 rooms'
#  '1 rooms' '1.2 rooms' '1.5 rooms' '1.7 rooms' '1.8 rooms' '1.4 rooms'
#  '2 rooms' '1.1 rooms' '2.4 rooms']
#
# Column Basic_Facilities:
# ----------------------
# Data type of column Basic_Facilities:  object
# Unique values in column Basic_Facilities:
# ['~98.92%' '99.25%' '99.3%' '93.33%' '99.81%' '90.64%' '87.68%' '97.66%'
#  '99.52%' '94.35%' '99.6%' '99.46%' '99.9%' '99.65%' '96.55%' '100%'
#  '99.82%' '~96.1%' '99.4%' '93.6%' '97.49%' '88.8%' '88.22%' '99.93%'
#  '74.14%' '99.95%' '~99.99%' '97.72%' '99.08%' '86.2%' '98.46%' '99.8%'
#  '64.13%' '99.75%' '99.98%' '95.12%' '99.5%' '99.91%']
#
# Column Housing_Expenditure:
# ----------------------
# Data type of column Housing_Expenditure:  object
# Unique values in column Housing_Expenditure:
# ['19.4%' '20.8%' '20%' '~20.5%' '22.9%' '18.4%' '17%' '23.4%' '23.3%'
#  '23.1%' '20.7%' '21.8%' '19.9%' '20.6%' '22.5%' '14.7%' '17.8%' '19.6%'
#  '25%' '17.7%' '21.2%' '17.4%' '27.4%' '18.2%' '18.1%' '21.7%' '20.1%'
#  '21.4%' '18.9%' '23.2%' '18.3%']
#
# Column Net_Disposable_Income:
# ----------------------
# Data type of column Net_Disposable_Income:  object
# Unique values in column Net_Disposable_Income:
# ['37433USD' '37001USD' '34884USD' '~12924USD' '34421USD' '~18477USD'
#  '~13090USD' '16517USD' '26664USD' '33774USD' '23784USD' '33471USD'
#  '34375USD' '38971USD' '20791USD' '21026USD' '~37549USD' '29488USD'
#  '~27701USD' '29431USD' '28872USD' '24590USD' '19783USD' '26976USD'
#  '44773USD' '16269USD' '34984USD' '39024USD' '39144USD' '23675USD'
#  '24877USD' '19546USD' '21149USD' '25250USD' '9338USD' '27155USD'
#  '33730USD' '39697USD' '~19482USD' '33049USD' '51147USD']
#
# Column Social_Inequality_Income:
# ----------------------
# Data type of column Social_Inequality_Income:  float64
# Unique values in column Social_Inequality_Income:
# [ 7.44  5.84  4.52   nan  6.51 21.98  4.21  4.68  6.63  4.62  5.66  6.65
#   5.92  5.1   9.59  9.14  9.27  8.47  9.55  7.19 12.    5.57  7.28  5.31
#   5.64  6.7   4.69  4.43 92.47  8.87  5.18  5.96  8.97 13.61]
#
# Column Net_wealth:
# ----------------------
# Data type of column Net_wealth:  object
# Unique values in column Net_wealth:
# ['528768USD' '309637USD' '447607USD' '~95092USD' '478240USD' '135787USD'
#  '~87431USD' '~118723USD' '~152114USD' '149864USD' '188627USD' '230032USD'
#  '298639USD' '304317USD' '148323USD' '150296USD' '~602377USD' '370341USD'
#  '~345228USD' '295020USD' '294735USD' '362340USD' '79245USD' '182039USD'
#  '941162USD' '~121741USD' '248599USD' '514162USD' '268358USD' '233221USD'
#  '255303USD' '~103017USD' '171425USD' '233286USD' '~91755USD' '366534USD'
#  '~435100USD' '~862378USD' '~99761USD' '524422USD' '684500USD']
#
# Column Employment_Rate:
# ----------------------
# Data type of column Employment_Rate:  object
# Unique values in column Employment_Rate:
# ['72.69%' '72.4%' '64.71%' '56.7%' '69.97%' '55.84%' '57.55%' '54.84%'
#  '74.38%' '74.46%' '73.84%' '72.24%' '65.28%' '76.69%' '56.26%' '69.68%'
#  '77.94%' '68.14%' '66.78%' '58.08%' '77.27%' '65.86%' '71.62%' '71.61%'
#  '67.24%' '59.45%' '77.79%' '76.8%' '74.67%' '68.67%' '69.02%' '69.99%'
#  '67.52%' '70.86%' '38.52%' '61.95%' '75.46%' '79.93%' '47.52%' '75.26%'
#  '67.07%']
#
# Column Gender_Inequality_Employment:
# ----------------------
# Data type of column Gender_Inequality_Employment:  float64
# Unique values in column Gender_Inequality_Employment:
# [1.12 1.41 1.1  1.4  1.58 1.64 1.21 1.08 1.06 1.04 1.11 1.37 1.24 1.17
#  1.19 1.32 1.02 1.69 1.13 1.05 1.23 1.14 1.09 1.31 2.2  1.16]
#
# Column Social_Inequality_Employment:
# ----------------------
# Data type of column Social_Inequality_Employment:  float64
# Unique values in column Social_Inequality_Employment:
# [2.07 2.5  2.29 1.45 1.8  1.44  nan 1.33 5.31 1.91 1.59 2.93 1.94 1.77
#  1.68 2.4  1.2  2.28 2.37 2.7  1.34 2.55 3.58 1.58 1.25 1.64 1.82 1.35
#  2.98 6.35 4.03 1.84 1.81 2.34 1.38 1.48 1.96 1.43]
#
# Column Long_Term_Unemployment:
# ----------------------
# Data type of column Long_Term_Unemployment:  object
# Unique values in column Long_Term_Unemployment:
# ['1.03%' '1.32%' '2.31%' '~6.89%' '0.49%' '~4.15%' '1.09%' '1.5%' '0.57%'
#  '0.92%' '1.17%' '1.22%' '2.94%' '1.2%' '10.84%' '1.16%' '0.67%' '0.21%'
#  '4.8%' '0.78%' '0.02%' '2.21%' '2.46%' '1.73%' '0.06%' '0.41%' '0.93%'
#  '0.63%' '2.27%' '3.01%' '1.93%' '17.9%' '4.99%' '0.97%' '1.67%' '3.28%'
#  '0.91%' '0.45%']
#
# Column Gender_Inequality_Unemployment:
# ----------------------
# Data type of column Gender_Inequality_Unemployment:  float64
# Unique values in column Gender_Inequality_Unemployment:
# [1.09 1.27 1.24  nan 1.42 2.22 3.51 1.26 1.64 1.22 1.02 1.45 1.53 1.66
#  1.41 1.21 2.31 1.01 1.61 1.07 1.15 1.1  1.32 1.06 1.55 1.49 1.11 1.97
#  1.16]
#
# Column Social_Inequality_Unemployment:
# ----------------------
# Data type of column Social_Inequality_Unemployment:  float64
# Unique values in column Social_Inequality_Unemployment:
# [ 2.14  7.58  3.86   nan  2.1   1.45  1.76  2.84  2.64  2.55  4.73  1.65
#  11.7   2.41  1.47  3.65  1.2  10.28  1.72  1.92  2.26  7.41  4.21  1.07
#   6.58  9.97  3.64  2.2   2.77  9.14  2.48  1.04  1.83  2.65]
#
# Column Personal_Earnings:
# ----------------------
# Data type of column Personal_Earnings:  object
# Unique values in column Personal_Earnings:
# ['55206USD' '53132USD' '54327USD' '~13637USD' '55342USD' '26729USD'
#  '~13388USD' '~18510USD' '29885USD' '58430USD' '30720USD' '46230USD'
#  '45581USD' '53745USD' '27207USD' '25409USD' '67488USD' '49474USD'
#  '39322USD' '37769USD' '38515USD' '41960USD' '29876USD' '31811USD'
#  '65854USD' '16230USD' '58828USD' '45269USD' '55780USD' '32527USD'
#  '28410USD' '~25612USD' '23619USD' '41445USD' '~11168USD' '37922USD'
#  '47020USD' '64824USD' '~25824USD' '47147USD' '69392USD']
#
# Column Gender_Inequality_Earnings:
# ----------------------
# Data type of column Gender_Inequality_Earnings:  float64
# Unique values in column Gender_Inequality_Earnings:
# [1.15 1.23 1.05  nan 1.17 1.2  1.1  1.25 1.26 1.21 1.08 1.22 1.32 1.34
#  1.44 1.3  1.03 1.09 1.12 1.33 1.11 1.19 1.24]
#
# Column Social_Inequality_Earnings:
# ----------------------
# Data type of column Social_Inequality_Earnings:  float64
# Unique values in column Social_Inequality_Earnings:
# [2.19 2.1  1.77  nan 2.29 2.97 2.07 1.86 2.45 1.87 2.01 2.11 2.14 2.41
#  1.97 2.81 1.61 1.92 2.42 2.53 2.23 2.2  1.99 1.91 1.68 2.32 2.37 2.09
#  2.15 2.25 2.91]
#
# Column Job_Security:
# ----------------------
# Data type of column Job_Security:  object
# Unique values in column Job_Security:
# ['3.07%' '2.3%' '2.41%' '~10.01%' '3.8%' '7.02%' '~9.25%' '~9.27%' '2.29%'
#  '4.47%' '5.42%' '2.24%' '1.42%' '21.68%' '3.76%' '0.99%' '2.64%' '4.63%'
#  '8.63%' '2.68%' '2.95%' '6.29%' '~5.38%' '2.17%' '4.04%' '2.55%' '4.5%'
#  '2.85%' '5.05%' '8.13%' '~4.50%' '8.78%' '5.94%' '~24.13%' '15.81%'
#  '4.39%' '~2.40%' '12.97%' '3.3%' '4.25%']
#
# Column Quality_of_Support_Network:
# ----------------------
# Data type of column Quality_of_Support_Network:  object
# Unique values in column Quality_of_Support_Network:
# ['93%' '92%' '90%' '83%' '88%' '80%' '82%' '96%' '95%' '94%' '78%' '98%'
#  '89%' '91%' '77%' '87%' '85%']
#
# Column Gender_Inequality_Community:
# ----------------------
# Data type of column Gender_Inequality_Community:  float64
# Unique values in column Gender_Inequality_Community:
# [1.   1.05 1.08 1.01 1.09 1.07 1.02 1.04 1.06 1.1  1.16 1.03]
#
# Column Social_Inequality_Community:
# ----------------------
# Data type of column Social_Inequality_Community:  float64
# Unique values in column Social_Inequality_Community:
# [1.03 1.04 1.07 1.02 1.08 1.15 1.06 1.   1.12 1.01  nan 1.11 1.05]
#
# Column Educational_Attainment:
# ----------------------
# Data type of column Educational_Attainment:  object
# Unique values in column Educational_Attainment:
# ['84%' '86%' '80%' '57%' '92%' '67%' '59%' '43%' '94%' '82%' '91%' '81%'
#  '76%' '85%' '88%' '63%' '~95%' '89%' '74%' '42%' '93%' '55%' '95%' '90%'
#  '48%']
#
# Column Gender_Inequality_Education:
# ----------------------
# Data type of column Gender_Inequality_Education:  float64
# Unique values in column Gender_Inequality_Education:
# [1.   1.06 1.04 1.13 1.03 1.08 1.09 1.02 1.05 1.07 1.01  nan 1.14 1.1
#  1.2 ]
#
# Column Student_Skills:
# ----------------------
# Data type of column Student_Skills:  object
# Unique values in column Student_Skills:
# ['499 score' '491 score' '500 score' '400 score' '517 score' '438 score'
#  '406 score' '415 score' '495 score' '501 score' '526 score' '516 score'
#  '494 score' '453 score' '479 score' '481 score' '505 score' '465 score'
#  '477 score' '520 score' '487 score' '480 score' '416 score' '502 score'
#  '503 score' '497 score' '513 score' '492 score' '469 score' '504 score'
#  '~390 score' '~482 score' '498 score' '462 score']
#
# Column Gender_Inequality_Skills:
# ----------------------
# Data type of column Gender_Inequality_Skills:  float64
# Unique values in column Gender_Inequality_Skills:
# [1.02 1.01 1.   1.05 1.04 1.06 1.03  nan]
#
# Column Social_Inequality_Skills:
# ----------------------
# Data type of column Social_Inequality_Skills:  float64
# Unique values in column Social_Inequality_Skills:
# [1.19 1.21 1.25 1.26 1.14 1.23 1.24 1.17 1.12 1.16 1.2  1.27 1.3  1.15
#  1.29  nan]
#
# Column Years_in_Education:
# ----------------------
# Data type of column Years_in_Education:  object
# Unique values in column Years_in_Education:
# ['20.4 years' '17 years' '19.5 years' '16.2 years' '17.4 years'
#  '14.1 years' '~16.5 years' '17.8 years' '19.3 years' '17.6 years'
#  '19.8 years' '16.6 years' '18.2 years' '19.2 years' '16.5 years'
#  '18.8 years' '17.9 years' '15.6 years' '16.7 years' '16.4 years'
#  '17.2 years' '18.5 years' '15 years' '15.4 years' '17.5 years'
#  '18.4 years' '15.7 years' '~15.3 years' '19.7 years' '18.7 years'
#  '16.8 years' '17.3 years']
#
# Column Gender_Inequality_Years_Education:
# ----------------------
# Data type of column Gender_Inequality_Years_Education:  float64
# Unique values in column Gender_Inequality_Years_Education:
# [1.02 1.04 1.07 1.05  nan 1.   1.01 1.08 1.06 1.03]
#
# Column Air_Pollution:
# ----------------------
# Data type of column Air_Pollution:  object
# Unique values in column Air_Pollution:
# ['6.7 micrograms' '12.2 micrograms' '12.8 micrograms' '11.7 micrograms'
#  '7.1 micrograms' '23.4 micrograms' '22.6 micrograms' '17.5 micrograms'
#  '17 micrograms' '10 micrograms' '5.9 micrograms' '5.5 micrograms'
#  '11.4 micrograms' '12 micrograms' '14.5 micrograms' '16.7 micrograms'
#  '6.4 micrograms' '7.8 micrograms' '19.7 micrograms' '15.9 micrograms'
#  '13.7 micrograms' '27.3 micrograms' '12.7 micrograms' '10.5 micrograms'
#  '20.3 micrograms' '6 micrograms' '22.8 micrograms' '8.3 micrograms'
#  '11.8 micrograms' '18.5 micrograms' '28.5 micrograms' '5.8 micrograms'
#  '10.1 micrograms' '27.1 micrograms' '7.7 micrograms']
#
# Column Water_Quality:
# ----------------------
# Data type of column Water_Quality:  object
# Unique values in column Water_Quality:
# ['92%' '79%' '70%' '90%' '62%' '82%' '87%' '89%' '93%' '86%' '97%' '78%'
#  '91%' '67%' '81%' '80%' '77%' '83%' '85%' '75%' '98%' '72%' '76%' '96%'
#  '88%']
#
# Column Voter_Turnout:
# ----------------------
# Data type of column Voter_Turnout:  object
# Unique values in column Voter_Turnout:
# ['91.9%' '75.6%' '88.4%' '79.8%' '67.7%' '46.7%' '53.4%' '65.7%' '61.9%'
#  '84.6%' '63.7%' '68.7%' '74.6%' '76.2%' '57.8%' '69.7%' '81.2%' '62.8%'
#  '67.4%' '72.9%' '52.7%' '77.2%' '54.6%' '57.4%' '89.7%' '63.4%' '78.7%'
#  '82.2%' '78.2%' '68.2%' '48.6%' '67.5%' '65.8%' '52.6%' '66.1%' '71.8%'
#  '87.2%' '45.1%' '86.2%' '67.6%' '65.4%']
#
# Column Gender_Inequality_Voter:
# ----------------------
# Data type of column Gender_Inequality_Voter:  float64
# Unique values in column Gender_Inequality_Voter:
# [1.03 1.04 1.02 1.    nan 1.11 1.1  1.08 1.01 1.05 1.09 1.16 1.06 1.12
#  1.07]
#
# Column Social_Inequality_Voter:
# ----------------------
# Data type of column Social_Inequality_Voter:  float64
# Unique values in column Social_Inequality_Voter:
# [1.07 1.2   nan 1.03 1.06 1.24 1.38 1.05 1.23 1.21 1.27 1.02 1.19 1.08
#  1.1  1.12 1.33 1.13 1.   1.29 1.04 1.53 1.22 1.16 1.37 1.46 1.51]
#
# Column Stakeholder_Engagement:
# ----------------------
# Data type of column Stakeholder_Engagement:  object
# Unique values in column Stakeholder_Engagement:
# ['2.7 index' '1.3 index' '2 index' '2.2 index' '2.9 index' '1.4 index'
#  '1.8 index' '1.6 index' '2.1 index' '1.2 index' '2.5 index' '2.4 index'
#  '1.7 index' '3.2 index' '2.6 index' '1.5 index' '~0.8 index' '3 index'
#  '~1.6 index' '2.3 index' '3.1 index']
#
# Column Life_Expectancy:
# ----------------------
# Data type of column Life_Expectancy:  object
# Unique values in column Life_Expectancy:
# ['83 years' '82 years' '82.1 years' '75.9 years' '80.6 years' '76.7 years'
#  '80.5 years' '79.3 years' '81.5 years' '78.8 years' '82.9 years'
#  '81.4 years' '81.7 years' '76.4 years' '83.2 years' '82.8 years'
#  '83.6 years' '84.4 years' '83.3 years' '75.5 years' '82.7 years'
#  '75.1 years' '82.2 years' '78 years' '81.8 years' '73.2 years'
#  '77.8 years' '81.6 years' '64.2 years' '83.9 years' '84 years'
#  '78.6 years' '81.3 years' '78.9 years']
#
# Column Gender_Inequality_Life_Expectancy:
# ----------------------
# Data type of column Gender_Inequality_Life_Expectancy:  float64
# Unique values in column Gender_Inequality_Life_Expectancy:
# [1.05 1.06 1.1  1.07 1.09 1.08 1.11 1.04 1.13 1.15 1.12]
#
# Column Self_Reported_Health:
# ----------------------
# Data type of column Self_Reported_Health:  object
# Unique values in column Self_Reported_Health:
# ['85.2%' '71.2%' '74%' '~69.8%' '88.8%' '59.7%' '80.4%' '~73.5%' '61.9%'
#  '69.6%' '56.5%' '68.3%' '66.6%' '65.5%' '79.1%' '58.2%' '76.6%' '83.9%'
#  '73.8%' '72.8%' '36.6%' '33.7%' '47.1%' '46.1%' '71.7%' '74.8%' '86.2%'
#  '74.7%' '59.8%' '50%' '~43%' '65.1%' '~68.0%' '75.2%' '76%' '81.2%'
#  '66.9%' '73.2%' '87.9%']
#
# Column Gender_Inequality_Health:
# ----------------------
# Data type of column Gender_Inequality_Health:  float64
# Unique values in column Gender_Inequality_Health:
# [1.01 1.02 1.06  nan 1.14 1.08 1.09 1.07 1.03 1.05 1.13 1.11 1.   1.04
#  1.27 1.23 1.22 1.1  1.3  1.15]
#
# Column Social_Inequality_Health:
# ----------------------
# Data type of column Social_Inequality_Health:  float64
# Unique values in column Social_Inequality_Health:
# [1.11 1.36 1.52  nan 1.14 1.38 2.11 1.32 2.37 1.54 1.25 1.63 1.12 1.31
#  1.3  1.13 1.42 1.53 2.79 2.55 1.17 1.44 1.66 1.62 1.19 1.35 1.27 1.34]
#
# Column Life_Satisfaction_2:
# ----------------------
# Data type of column Life_Satisfaction_2:  object
# Unique values in column Life_Satisfaction_2:
# ['7.1 rate' '7.2 rate' '6.8 rate' '6.1 rate' '7 rate' '6.2 rate'
#  '5.7 rate' '6.3 rate' '6.9 rate' '7.5 rate' '6.5 rate' '7.9 rate'
#  '6.7 rate' '7.3 rate' '5.8 rate' '6 rate' '7.6 rate' '6.4 rate'
#  '7.4 rate' '5.5 rate' '4.9 rate']
#
# Column Gender_Inequality_Satisfaction:
# ----------------------
# Data type of column Gender_Inequality_Satisfaction:  float64
# Unique values in column Gender_Inequality_Satisfaction:
# [1.02 1.03 1.01 1.   1.04 1.09 1.08 1.05 1.06 1.13 1.12 1.07 1.26]
#
# Column Social_Inequality_Satisfaction:
# ----------------------
# Data type of column Social_Inequality_Satisfaction:  float64
# Unique values in column Social_Inequality_Satisfaction:
# [1.06 1.05 1.08 1.09 1.13 1.26 1.1  1.02 1.16 1.07 1.04 1.15  nan 1.14
#  1.01 1.12 1.11 1.19]
#
# Column Safe_at_Night:
# ----------------------
# Data type of column Safe_at_Night:  object
# Unique values in column Safe_at_Night:
# ['66.95%' '85.68%' '56.5%' '44.78%' '77.5%' '40.69%' '49.52%' '47.12%'
#  '77.43%' '85.26%' '79.49%' '87.55%' '73.97%' '76.15%' '68.8%' '73.71%'
#  '85.38%' '76.32%' '79.77%' '72.82%' '76.75%' '82.02%' '72.32%' '62.22%'
#  '86.55%' '42.28%' '83.16%' '66.15%' '93.16%' '71.14%' '82.88%' '63.59%'
#  '75.87%' '90.56%' '39.98%' '80.4%' '79.25%' '85.9%' '58.66%' '78.36%'
#  '78.07%']
#
# Column Gender_Inequality_Safety:
# ----------------------
# Data type of column Gender_Inequality_Safety:  float64
# Unique values in column Gender_Inequality_Safety:
# [1.5  1.09 1.42 1.61 1.31 1.77 1.19 1.62 1.23 1.27 1.2  1.11 1.33 1.28
#  1.18 1.14 1.24 1.07 1.69 1.1  1.26 1.22 1.34 1.12 1.15 1.32 1.13 1.6
#  1.04]
#
# Column Homicide_Rate:
# ----------------------
# Data type of column Homicide_Rate:  object
# Unique values in column Homicide_Rate:
# ['0.9 homicides' '0.5 homicides' '1.1 homicides' '19 homicides'
#  '1.2 homicides' '2.4 homicides' '23.1 homicides' '10 homicides'
#  '0.7 homicides' '1.9 homicides' '0.4 homicides' '1 homicides'
#  '0.3 homicides' '1.5 homicides' '0.2 homicides' '0.8 homicides'
#  '3.7 homicides' '2.47 homicides' '26.8 homicides' '0.6 homicides'
#  '1.3 homicides' '4.8 homicides' '13.7 homicides' '6 homicides']
#
# Column Gender_Inequality_Homicide:
# ----------------------
# Data type of column Gender_Inequality_Homicide:  float64
# Unique values in column Gender_Inequality_Homicide:
# [ 2.17  1.    1.75 10.76  2.57  6.   10.49 10.11  1.33  5.17  2.    4.
#   1.62  2.4   8.    3.43  2.33  1.29  3.05  4.17  1.5   9.18  1.6   1.4
#   2.67  2.5   3.5   1.67  6.86  1.8   3.    3.8 ]
#
# Column Long_Hours:
# ----------------------
# Data type of column Long_Hours:  object
# Unique values in column Long_Hours:
# ['12.5%' '5.3%' '4.3%' '5.6%' '3.3%' '7.7%' '23.7%' '22%' '4.5%' '1.1%'
#  '2.2%' '3.6%' '3.9%' '1.5%' '11.7%' '4.7%' '14.1%' '~15.7%' '~19.7%'
#  '1.6%' '1%' '2.8%' '27%' '0.3%' '14%' '1.4%' '4.2%' '0.1%' '15.4%' '2.5%'
#  '0.9%' '0.4%' '25%' '10.8%' '10.4%']
#
# Column Gender_Inequality_Long_Hours:
# ----------------------
# Data type of column Gender_Inequality_Long_Hours:  float64
# Unique values in column Gender_Inequality_Long_Hours:
# [ 3.06  3.45  2.21  2.03  4.5   1.93  1.65  2.2   3.4  20.77  2.25  2.47
#   1.96  3.11  2.43  2.27  3.56  4.69  3.17  2.     nan  2.51  1.4   1.66
#   1.9   5.97  3.72  5.04  2.46  3.62  3.02  2.69  1.89  2.52  2.64  1.61
#   1.35  2.09]
#
# Column Free_Time:
# ----------------------
# Data type of column Free_Time:  object
# Unique values in column Free_Time:
# ['14.4 hours' '14.5 hours' '15.5 hours' '~14.6 hours' '14.6 hours'
#  '~14.0 hours' '~13.3 hours' '~13.5 hours' '~15.1 hours' '~15.7 hours'
#  '15 hours' '15.2 hours' '16.2 hours' '15.6 hours' '15.1 hours'
#  '~14.5 hours' '~14.3 hours' '16.5 hours' '14.1 hours' '14.8 hours'
#  '15.4 hours' '14.9 hours' '15.7 hours' '14.7 hours' '~15.0 hours'
#  '~14.2 hours' '~15.3 hours']
#
# Column Gender_Inequality_Free_Time:
# ----------------------
# Data type of column Gender_Inequality_Free_Time:  float64
# Unique values in column Gender_Inequality_Free_Time:
# [1.08 1.02  nan 1.01 1.06 1.03 1.04 1.07 1.09 1.   1.05]

# %% [markdown]
# ## 3. Clean the raw data
#
# We remove the non-numeric characters from the columns with type "object" (except for column "Country") and convert the numeric value into float.

# %%
# Function to remove all not numeric characters from a string:
def clean_mixed_column2(column):
    """
    Cleans a DataFrame column by removing non numeric characters such as '%','~' symbols and letters, and after that converting the value to float.
    
    Parameters:
       column (Pandas.Series): The column of a data frame to clean.
    
    Returns:
       Pandas.Series: The cleaned column as a Pandas.Series
    """
    return column.astype(str).apply(lambda x: float(re.sub(r'[^0-9.]', '', x)))

# %%
# Select all "object" columns of the dataframe:
object_columns = df_raw.select_dtypes(include=['object'])

print(object_columns)
# Out:
#                Country Rooms_per_person Basic_Facilities Housing_Expenditure  \
# 0            Australia       ~2.3 rooms          ~98.92%               19.4%
# 1              Austria        1.6 rooms           99.25%               20.8%
# 2              Belgium        2.1 rooms            99.3%                 20%
# 3               Brazil       ~1.1 rooms           93.33%              ~20.5%
# 4               Canada        2.6 rooms           99.81%               22.9%
# 5                Chile        1.9 rooms           90.64%               18.4%
# 6             Colombia          1 rooms           87.68%              ~20.5%
# 7           Costa Rica        1.2 rooms           97.66%                 17%
# 8              Czechia        1.5 rooms           99.52%               23.4%
# 9              Denmark        1.9 rooms           99.52%               23.3%
# 10             Estonia        1.7 rooms           94.35%                 17%
# 11             Finland        1.9 rooms            99.6%               23.1%
# 12              France        1.8 rooms           99.46%               20.7%
# 13             Germany        1.8 rooms            99.9%                 20%
# 14              Greece        1.2 rooms           99.65%               21.8%
# 15             Hungary        1.4 rooms           96.55%               19.9%
# 16             Iceland        1.6 rooms             100%              ~20.5%
# 17             Ireland        2.1 rooms           99.82%               20.6%
# 18              Israel        1.2 rooms           ~96.1%              ~20.5%
# 19               Italy        1.4 rooms            99.4%               22.5%
# 20               Japan        1.9 rooms            93.6%               21.8%
# 21               Korea        1.5 rooms           97.49%               14.7%
# 22              Latvia        1.2 rooms            88.8%               20.8%
# 23           Lithuania        1.5 rooms           88.22%               18.4%
# 24          Luxembourg          2 rooms           99.93%               20.7%
# 25              Mexico        1.1 rooms           74.14%               17.8%
# 26         Netherlands          2 rooms           99.95%               19.6%
# 27         New Zealand        2.4 rooms          ~99.99%                 25%
# 28              Norway        2.1 rooms             100%               17.7%
# 29              Poland        1.1 rooms           97.72%               21.2%
# 30            Portugal        1.7 rooms           99.08%               19.6%
# 31  Russian Federation          1 rooms            86.2%               17.4%
# 32     Slovak Republic        1.1 rooms           98.46%               27.4%
# 33            Slovenia        1.6 rooms            99.8%               18.2%
# 34        South Africa          1 rooms           64.13%               18.1%
# 35               Spain        1.9 rooms           99.75%               21.7%
# 36              Sweden        1.7 rooms             100%               20.1%
# 37         Switzerland        1.9 rooms           99.98%               21.4%
# 38             Türkiye          1 rooms           95.12%               18.9%
# 39      United Kingdom          2 rooms            99.5%               23.2%
# 40       United States        2.4 rooms           99.91%               18.3%
#
#    Net_Disposable_Income  Net_wealth Employment_Rate Long_Term_Unemployment  \
# 0               37433USD   528768USD          72.69%                  1.03%
# 1               37001USD   309637USD           72.4%                  1.32%
# 2               34884USD   447607USD          64.71%                  2.31%
# 3              ~12924USD   ~95092USD           56.7%                 ~6.89%
# 4               34421USD   478240USD          69.97%                  0.49%
# 5              ~18477USD   135787USD          55.84%                 ~4.15%
# 6              ~13090USD   ~87431USD          57.55%                  1.09%
# 7               16517USD  ~118723USD          54.84%                   1.5%
# 8               26664USD  ~152114USD          74.38%                  0.57%
# 9               33774USD   149864USD          74.46%                  0.92%
# 10              23784USD   188627USD          73.84%                  1.17%
# 11              33471USD   230032USD          72.24%                  1.22%
# 12              34375USD   298639USD          65.28%                  2.94%
# 13              38971USD   304317USD          76.69%                   1.2%
# 14              20791USD   148323USD          56.26%                 10.84%
# 15              21026USD   150296USD          69.68%                  1.16%
# 16             ~37549USD  ~602377USD          77.94%                  0.67%
# 17              29488USD   370341USD          68.14%                  1.16%
# 18             ~27701USD  ~345228USD          66.78%                  0.21%
# 19              29431USD   295020USD          58.08%                   4.8%
# 20              28872USD   294735USD          77.27%                  0.78%
# 21              24590USD   362340USD          65.86%                  0.02%
# 22              19783USD    79245USD          71.62%                  2.21%
# 23              26976USD   182039USD          71.61%                  2.46%
# 24              44773USD   941162USD          67.24%                  1.73%
# 25              16269USD  ~121741USD          59.45%                  0.06%
# 26              34984USD   248599USD          77.79%                  0.92%
# 27              39024USD   514162USD           76.8%                  0.41%
# 28              39144USD   268358USD          74.67%                  0.93%
# 29              23675USD   233221USD          68.67%                  0.63%
# 30              24877USD   255303USD          69.02%                  2.27%
# 31              19546USD  ~103017USD          69.99%                  1.09%
# 32              21149USD   171425USD          67.52%                  3.01%
# 33              25250USD   233286USD          70.86%                  1.93%
# 34               9338USD   ~91755USD          38.52%                  17.9%
# 35              27155USD   366534USD          61.95%                  4.99%
# 36              33730USD  ~435100USD          75.46%                  0.97%
# 37              39697USD  ~862378USD          79.93%                  1.67%
# 38             ~19482USD   ~99761USD          47.52%                  3.28%
# 39              33049USD   524422USD          75.26%                  0.91%
# 40              51147USD   684500USD          67.07%                  0.45%
#
#    Personal_Earnings Job_Security  ... Water_Quality Voter_Turnout  \
# 0           55206USD        3.07%  ...           92%         91.9%
# 1           53132USD         2.3%  ...           92%         75.6%
# 2           54327USD        2.41%  ...           79%         88.4%
# 3          ~13637USD      ~10.01%  ...           70%         79.8%
# 4           55342USD         3.8%  ...           90%         67.7%
# 5           26729USD        7.02%  ...           62%         46.7%
# 6          ~13388USD       ~9.25%  ...           82%         53.4%
# 7          ~18510USD       ~9.27%  ...           87%         65.7%
# 8           29885USD        2.29%  ...           89%         61.9%
# 9           58430USD        4.47%  ...           93%         84.6%
# 10          30720USD        5.42%  ...           86%         63.7%
# 11          46230USD        2.24%  ...           97%         68.7%
# 12          45581USD        3.07%  ...           78%         74.6%
# 13          53745USD        1.42%  ...           91%         76.2%
# 14          27207USD       21.68%  ...           67%         57.8%
# 15          25409USD        3.76%  ...           81%         69.7%
# 16          67488USD        0.99%  ...           97%         81.2%
# 17          49474USD        2.64%  ...           80%         62.8%
# 18          39322USD        4.63%  ...           77%         67.4%
# 19          37769USD        8.63%  ...           77%         72.9%
# 20          38515USD        2.68%  ...           87%         52.7%
# 21          41960USD        2.95%  ...           82%         77.2%
# 22          29876USD        6.29%  ...           83%         54.6%
# 23          31811USD       ~5.38%  ...           83%         57.4%
# 24          65854USD        2.17%  ...           85%         89.7%
# 25          16230USD        4.04%  ...           75%         63.4%
# 26          58828USD        2.55%  ...           91%         78.7%
# 27          45269USD         4.5%  ...           85%         82.2%
# 28          55780USD        2.85%  ...           98%         78.2%
# 29          32527USD        5.05%  ...           82%         68.2%
# 30          28410USD        8.13%  ...           89%         48.6%
# 31         ~25612USD       ~4.50%  ...           62%         67.5%
# 32          23619USD        8.78%  ...           81%         65.8%
# 33          41445USD        5.94%  ...           93%         52.6%
# 34         ~11168USD      ~24.13%  ...           72%         66.1%
# 35          37922USD       15.81%  ...           76%         71.8%
# 36          47020USD        4.39%  ...           97%         87.2%
# 37          64824USD       ~2.40%  ...           96%         45.1%
# 38         ~25824USD       12.97%  ...           62%         86.2%
# 39          47147USD         3.3%  ...           82%         67.6%
# 40          69392USD        4.25%  ...           88%         65.4%
#
#    Stakeholder_Engagement Life_Expectancy Self_Reported_Health  \
# 0               2.7 index        83 years                85.2%
# 1               1.3 index        82 years                71.2%
# 2                 2 index      82.1 years                  74%
# 3               2.2 index      75.9 years               ~69.8%
# 4               2.9 index      82.1 years                88.8%
# 5               1.3 index      80.6 years                59.7%
# 6               1.4 index      76.7 years                80.4%
# 7               1.8 index      80.5 years               ~73.5%
# 8               1.6 index      79.3 years                61.9%
# 9                 2 index      81.5 years                69.6%
# 10              2.7 index      78.8 years                56.5%
# 11              2.2 index      82.1 years                68.3%
# 12              2.1 index      82.9 years                66.6%
# 13              1.8 index      81.4 years                65.5%
# 14              1.8 index      81.7 years                79.1%
# 15              1.2 index      76.4 years                58.2%
# 16              2.1 index      83.2 years                76.6%
# 17              1.3 index      82.8 years                83.9%
# 18              2.5 index      82.9 years                73.8%
# 19              2.5 index      83.6 years                72.8%
# 20              1.4 index      84.4 years                36.6%
# 21              2.9 index      83.3 years                33.7%
# 22              2.2 index      75.5 years                47.1%
# 23              2.4 index      76.4 years                46.1%
# 24              1.7 index      82.7 years                71.7%
# 25              3.2 index      75.1 years                65.5%
# 26              2.6 index      82.2 years                74.8%
# 27              2.5 index      82.1 years                86.2%
# 28              2.2 index        83 years                74.7%
# 29              2.6 index        78 years                59.8%
# 30              1.5 index      81.8 years                  50%
# 31             ~0.8 index      73.2 years                 ~43%
# 32                3 index      77.8 years                65.1%
# 33              2.5 index      81.6 years                66.6%
# 34             ~1.6 index      64.2 years               ~68.0%
# 35              1.8 index      83.9 years                75.2%
# 36                2 index      83.2 years                  76%
# 37              2.3 index        84 years                81.2%
# 38              1.5 index      78.6 years                66.9%
# 39              3.1 index      81.3 years                73.2%
# 40              3.1 index      78.9 years                87.9%
#
#    Life_Satisfaction_2 Safe_at_Night   Homicide_Rate Long_Hours    Free_Time
# 0             7.1 rate        66.95%   0.9 homicides      12.5%   14.4 hours
# 1             7.2 rate        85.68%   0.5 homicides       5.3%   14.5 hours
# 2             6.8 rate         56.5%   1.1 homicides       4.3%   15.5 hours
# 3             6.1 rate        44.78%    19 homicides       5.6%  ~14.6 hours
# 4               7 rate         77.5%   1.2 homicides       3.3%   14.6 hours
# 5             6.2 rate        40.69%   2.4 homicides       7.7%  ~14.0 hours
# 6             5.7 rate        49.52%  23.1 homicides      23.7%  ~13.3 hours
# 7             6.3 rate        47.12%    10 homicides        22%  ~13.5 hours
# 8             6.9 rate        77.43%   0.7 homicides       4.5%  ~15.1 hours
# 9             7.5 rate        85.26%   0.5 homicides       1.1%  ~15.7 hours
# 10            6.5 rate        79.49%   1.9 homicides       2.2%     15 hours
# 11            7.9 rate        87.55%   1.2 homicides       3.6%   15.2 hours
# 12            6.7 rate        73.97%   0.4 homicides       7.7%   16.2 hours
# 13            7.3 rate        76.15%   0.4 homicides       3.9%   15.6 hours
# 14            5.8 rate         68.8%     1 homicides       4.5%     15 hours
# 15              6 rate        73.71%   0.9 homicides       1.5%   15.1 hours
# 16            7.6 rate        85.38%   0.3 homicides      11.7%  ~14.5 hours
# 17              7 rate        76.32%   0.5 homicides       4.7%   14.5 hours
# 18            7.2 rate        79.77%   1.5 homicides      14.1%  ~14.3 hours
# 19            6.5 rate        72.82%   0.5 homicides       3.3%   16.5 hours
# 20            6.1 rate        76.75%   0.2 homicides     ~15.7%   14.1 hours
# 21            5.8 rate        82.02%   0.8 homicides     ~19.7%   14.8 hours
# 22            6.2 rate        72.32%   3.7 homicides       1.6%  ~15.1 hours
# 23            6.4 rate        62.22%  2.47 homicides         1%  ~15.1 hours
# 24            7.4 rate        86.55%   0.2 homicides       2.8%  ~15.1 hours
# 25              6 rate        42.28%  26.8 homicides        27%  ~13.5 hours
# 26            7.5 rate        83.16%   0.6 homicides       0.3%   15.4 hours
# 27            7.3 rate        66.15%   1.3 homicides        14%   14.9 hours
# 28            7.3 rate        93.16%   0.6 homicides       1.4%   15.7 hours
# 29            6.1 rate        71.14%   0.5 homicides       4.2%   14.7 hours
# 30            5.8 rate        82.88%   0.7 homicides       5.6%  ~15.0 hours
# 31            5.5 rate        63.59%   4.8 homicides       0.1%  ~15.1 hours
# 32            6.5 rate        75.87%   0.8 homicides       4.2%  ~15.1 hours
# 33            6.5 rate        90.56%   0.4 homicides       5.6%  ~15.0 hours
# 34            4.9 rate        39.98%  13.7 homicides      15.4%  ~14.2 hours
# 35            6.5 rate         80.4%   0.7 homicides       2.5%   15.7 hours
# 36            7.3 rate        79.25%   1.1 homicides       0.9%  ~15.3 hours
# 37            7.5 rate         85.9%   0.3 homicides       0.4%  ~15.0 hours
# 38            4.9 rate        58.66%     1 homicides        25%   14.6 hours
# 39            6.8 rate        78.36%   0.2 homicides      10.8%   14.9 hours
# 40              7 rate        78.07%     6 homicides      10.4%   14.6 hours
#
# [41 rows x 25 columns]

# %%
# We want to clean all "object" columns of the dataframe except for "Country":
# Select "object" (string) columns except for "Country" column:
filtered_columns = [col for col in object_columns if col != 'Country']
print(filtered_columns)
# Out:
# ['Rooms_per_person', 'Basic_Facilities', 'Housing_Expenditure', 'Net_Disposable_Income', 'Net_wealth', 'Employment_Rate', 'Long_Term_Unemployment', 'Personal_Earnings', 'Job_Security', 'Quality_of_Support_Network', 'Educational_Attainment', 'Student_Skills', 'Years_in_Education', 'Air_Pollution', 'Water_Quality', 'Voter_Turnout', 'Stakeholder_Engagement', 'Life_Expectancy', 'Self_Reported_Health', 'Life_Satisfaction_2', 'Safe_at_Night', 'Homicide_Rate', 'Long_Hours', 'Free_Time']

# %%
# Creating a deep copy of the original dataframe and clean it:
df_clean = df_raw.copy()
for col in filtered_columns:
    df_clean[col] = clean_mixed_column2(df_raw[col])

# %% [markdown]
# ## 4. Check Clean Dataframe

# %%
df_clean.head(10)
# Out:
#       Country  Population  Visitors  Renewable_Energy  Housing  Income  Jobs  \
# 0   Australia        24.9       6.1               4.6      8.2     5.9   8.6
# 1     Austria         8.9      18.9              29.5      6.3     4.7   8.5
# 2     Belgium        11.5       6.2               5.1      7.6     5.2   8.0
# 3      Brazil       209.5       5.2              45.8      4.7     0.5   4.3
# 4      Canada        37.1      25.3              17.9      7.8     5.3   8.4
# 5       Chile        18.7       3.6              24.1      6.7     1.4   5.5
# 6    Colombia        49.7       NaN               NaN      4.1     0.5   5.2
# 7  Costa Rica         NaN       NaN               NaN      6.3     1.1   5.2
# 8     Czechia        10.7      24.0               7.5      5.4     2.5   7.7
# 9     Denmark         5.8      20.6              24.4      6.3     3.3   8.7
#
#    Community  Education  Environment  ...  Gender_Inequality_Satisfaction  \
# 0        7.7        8.6          8.9  ...                            1.02
# 1        7.2        6.8          7.6  ...                            1.03
# 2        6.0        7.9          5.8  ...                            1.01
# 3        2.7        2.3          4.8  ...                            1.03
# 4        7.5        7.8          8.6  ...                            1.00
# 5        5.3        4.5          1.1  ...                            1.02
# 6        1.3        1.4          4.1  ...                            1.01
# 7        2.6        2.0          5.9  ...                            1.04
# 8        9.1        7.8          6.3  ...                            1.00
# 9        8.3        8.0          8.3  ...                            1.03
#
#    Social_Inequality_Satisfaction  Safe_at_Night  Gender_Inequality_Safety  \
# 0                            1.06          66.95                      1.50
# 1                            1.05          85.68                      1.09
# 2                            1.08          56.50                      1.42
# 3                            1.09          44.78                      1.61
# 4                            1.05          77.50                      1.31
# 5                            1.13          40.69                      1.77
# 6                            1.26          49.52                      1.19
# 7                            1.08          47.12                      1.62
# 8                            1.10          77.43                      1.31
# 9                            1.02          85.26                      1.23
#
#    Homicide_Rate  Gender_Inequality_Homicide  Long_Hours  \
# 0            0.9                        2.17        12.5
# 1            0.5                        1.00         5.3
# 2            1.1                        1.75         4.3
# 3           19.0                       10.76         5.6
# 4            1.2                        2.57         3.3
# 5            2.4                        6.00         7.7
# 6           23.1                       10.49        23.7
# 7           10.0                       10.11        22.0
# 8            0.7                        1.33         4.5
# 9            0.5                        1.75         1.1
#
#    Gender_Inequality_Long_Hours  Free_Time  Gender_Inequality_Free_Time
# 0                          3.06       14.4                         1.08
# 1                          3.45       14.5                         1.02
# 2                          2.21       15.5                         1.02
# 3                          2.03       14.6                          NaN
# 4                          4.50       14.6                         1.01
# 5                          1.93       14.0                          NaN
# 6                          1.65       13.3                          NaN
# 7                          2.20       13.5                          NaN
# 8                          3.40       15.1                          NaN
# 9                         20.77       15.7                          NaN
#
# [10 rows x 63 columns]

# %%
# Check data type of the columns of the cleaned data frame:
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 63 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            41 non-null     object
#  1   Population                         39 non-null     float64
#  2   Visitors                           38 non-null     float64
#  3   Renewable_Energy                   37 non-null     float64
#  4   Housing                            41 non-null     float64
#  5   Income                             41 non-null     float64
#  6   Jobs                               41 non-null     float64
#  7   Community                          41 non-null     float64
#  8   Education                          41 non-null     float64
#  9   Environment                        41 non-null     float64
#  10  Civic_Engagement                   41 non-null     float64
#  11  Health                             41 non-null     float64
#  12  Life_Satisfaction                  41 non-null     float64
#  13  Safety                             41 non-null     float64
#  14  Work_Life_Balance                  41 non-null     float64
#  15  Rooms_per_person                   41 non-null     float64
#  16  Basic_Facilities                   41 non-null     float64
#  17  Housing_Expenditure                41 non-null     float64
#  18  Net_Disposable_Income              41 non-null     float64
#  19  Social_Inequality_Income           35 non-null     float64
#  20  Net_wealth                         41 non-null     float64
#  21  Employment_Rate                    41 non-null     float64
#  22  Gender_Inequality_Employment       41 non-null     float64
#  23  Social_Inequality_Employment       38 non-null     float64
#  24  Long_Term_Unemployment             41 non-null     float64
#  25  Gender_Inequality_Unemployment     39 non-null     float64
#  26  Social_Inequality_Unemployment     33 non-null     float64
#  27  Personal_Earnings                  41 non-null     float64
#  28  Gender_Inequality_Earnings         33 non-null     float64
#  29  Social_Inequality_Earnings         32 non-null     float64
#  30  Job_Security                       41 non-null     float64
#  31  Quality_of_Support_Network         41 non-null     float64
#  32  Gender_Inequality_Community        41 non-null     float64
#  33  Social_Inequality_Community        39 non-null     float64
#  34  Educational_Attainment             41 non-null     float64
#  35  Gender_Inequality_Education        40 non-null     float64
#  36  Student_Skills                     41 non-null     float64
#  37  Gender_Inequality_Skills           39 non-null     float64
#  38  Social_Inequality_Skills           39 non-null     float64
#  39  Years_in_Education                 41 non-null     float64
#  40  Gender_Inequality_Years_Education  39 non-null     float64
#  41  Air_Pollution                      41 non-null     float64
#  42  Water_Quality                      41 non-null     float64
#  43  Voter_Turnout                      41 non-null     float64
#  44  Gender_Inequality_Voter            39 non-null     float64
#  45  Social_Inequality_Voter            35 non-null     float64
#  46  Stakeholder_Engagement             41 non-null     float64
#  47  Life_Expectancy                    41 non-null     float64
#  48  Gender_Inequality_Life_Expectancy  41 non-null     float64
#  49  Self_Reported_Health               41 non-null     float64
#  50  Gender_Inequality_Health           39 non-null     float64
#  51  Social_Inequality_Health           35 non-null     float64
#  52  Life_Satisfaction_2                41 non-null     float64
#  53  Gender_Inequality_Satisfaction     41 non-null     float64
#  54  Social_Inequality_Satisfaction     39 non-null     float64
#  55  Safe_at_Night                      41 non-null     float64
#  56  Gender_Inequality_Safety           41 non-null     float64
#  57  Homicide_Rate                      41 non-null     float64
#  58  Gender_Inequality_Homicide         41 non-null     float64
#  59  Long_Hours                         41 non-null     float64
#  60  Gender_Inequality_Long_Hours       39 non-null     float64
#  61  Free_Time                          41 non-null     float64
#  62  Gender_Inequality_Free_Time        22 non-null     float64
# dtypes: float64(62), object(1)
# memory usage: 20.3+ KB

# %% [markdown]
# ## 5. Write clean data into csv file

# %%
# Save cleaned data frame into the /data/clean folder as betterlife.clean.csv :
df_clean.to_csv("../data/clean/betterlife.clean.csv", index=False)
